# %% [markdown]
# <a href="https://colab.research.google.com/github/victoregomezf-maker/seminario/blob/main/seminario_induccion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# TEXTO ENTRE COMILLAS - SE PUEDE CAMBIAR LA DATA A DISPOSICION  -NOMBRAR VARIABLES ASI (XX_1) SIN ESPACIO NI NADA
#W=5    Z=3    PRINT(W*Z) = 15
#String= Tipo texto, en comillas simples o dobles
#int:Enteros
#float:Numeros decimales
#Boolean: true or false, yes or not


# a**b= Potencia es igual a elevar "a" a la "b"
# % residuo de la division
# el // el resultado de la division la da en entero menor

# %%
W=5
Z=3
print(W*Z)
# Out:
# 15

# %%
w=5**3
print(w)
# Out:
# 125

# %%
y=2
x = y + 2
print(x)
# Out:
# 4

# %%
divi_1=100/54
print(divi_1)
# Out:
# 1.8518518518518519

# %%
divi_1=100//54
print(divi_1)
# Out:
# 1

# %%
V1=25
V2=V1%3
print(V2)
# Out:
# 1

# %%
SOFI=7
if SOFI<=7:
  print("hasta la vista baby")
# Out:
# hasta la vista baby

# %%
# Ejercicio 1
x=5.5
y=7.8
z=x**y
print(z)
# Out:
# 595427.6223755431

# %%
a=10


if a<5:
  print("Hola Sebas")
elif a>54:
  print("Viva bad bunny")
else:
  print("Hola Victor")
# Out:
# Hola Victor

# %%
print("Paso 1. Determinar el valor de las variables")
a=input("oye tu, ven aca. Que valor le ponemos a la variable a")
b=input("Tienes tiempo para declarar una segunda varible. Ingresa el valor de la variable b:"

)
print("El valor de a es:",a)
print("El valor de la variable b:", b)
wait=input("presione enter para continuar")
print("Paso 2. Que pasa si?")
print("Que crees que ocurra si imprimimos a+b?")
wait=input("presione enter para continuar")
print("El resultado de a+b, es:" +a+b)
print("Que crees que ocurra si imprimimos float(a) + float(b)")
wait=input("presione enter para continuar")
print("El resultado de a+b, es:", float(a) + float(b))
wait=input("presione enter para continuar")
print("Que crees que ocurra si imprimimos int(a) + int(b)")
wait=input("presione enter para continuar")
print("El resultado de a+b, es:", int(a) + int(b))
print("Paso 3. Que pasa si comparamos a y b de manera simple?")
wait=input("presione enter para continuar")
if int(a)<10:
    print("No pase la materia")
if int(a)>20:
    print("Pase la materia")
print("Final Paso 3")
print("Paso 4. Que pasa si comparamos a y b?")
print("Para comparar podemos usar las siguientes opciones:")
print("si queremos comparar si es igual usamos ==")
print("si queremos comparar si es menor <")
print("si queremos comparar si es mayor >")
print("si queremos comparar si es mayor o igual >=")
print("si queremos comparar si es menor o igual <=")
print("si queremos comparar si es diferente !=")
print("que crees que ocurra si comparamos el valor de a > b?")
wait=input("presione enter para continuar")
print("a > b, es: ", a>b)
wait=input("presione enter para continuar")
print("que crees que ocurra si comparamos el valor de a < b?")
wait=input("presione enter para continuar")
print("a < b, es: ", a<b)
print("que crees que ocurra si comparamos el valor de a >= b?")
wait=input("presione enter para continuar")
print("a >= b, es: ", a>=b)
print("que crees que ocurra si comparamos el valor de a <= b?")
wait=input("presione enter para continuar")
print("a <= b, es: ", a<=b)
print("que crees que ocurra si comparamos el valor de a == b?")
wait=input("Presione enter para continuar")
print("a == b, es: ", a==b)
print("que crees que ocurra si comparamos el valor de a != b?")
wait=input("Presione enter para continuar")
print("a != b, es: ", a!=b)
wait=input("Presione enter para continuar")
print("Paso 5. Que pasa si queremos imprimir un mensaje en vez de falso y verdadero")
a = int(a)

b = int(b)
wait=input("presione enter para continuar")
print(" es a == 5? ")
wait=input("presione enter para continuar")
if a == 5:
    print("Igual a 5")
print(" es a > 4? ")
wait=input("presione enter para continuar")
if a > 4 :
    print("mayor que 4")
# Out:
# Paso 1. Determinar el valor de las variables
# oye tu, ven aca. Que valor le ponemos a la variable a9
# Tienes tiempo para declarar una segunda varible. Ingresa el valor de la variable b:10
# El valor de a es: 9
# El valor de la variable b: 10
# presione enter para continuar
# Paso 2. Que pasa si?
# Que crees que ocurra si imprimimos a+b?
# presione enter para continuar
# El resultado de a+b, es:910
# Que crees que ocurra si imprimimos float(a) + float(b)
# presione enter para continuar
# El resultado de a+b, es: 19.0
# presione enter para continuar
# Que crees que ocurra si imprimimos int(a) + int(b)
# presione enter para continuar
# El resultado de a+b, es: 19
# Paso 3. Que pasa si comparamos a y b de manera simple?
# presione enter para continuar
# No pase la materia
# Final Paso 3
# Paso 4. Que pasa si comparamos a y b?
# Para comparar podemos usar las siguientes opciones:
# si queremos comparar si es igual usamos ==
# si queremos comparar si es menor <
# ...
